# %% [markdown]
# # Test 1 Machine learning (Question 1)
# ### Muzaffar Izamuddin bin Daud - P166246

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf
# %matplotlib inline

# %%
df = pd.read_csv("Question_1.csv")

# %%
df.head()
# Out:
#    age          job  marital          education  default housing loan  \
# 0   44  blue-collar  married           basic.4y  unknown     yes   no
# 1   53   technician  married            unknown       no      no   no
# 2   28   management   single  university.degree       no     yes   no
# 3   39     services  married        high.school       no      no   no
# 4   55      retired  married           basic.4y       no     yes   no
#
#     contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0  cellular   aug         thu  ...         1    999         0  nonexistent
# 1  cellular   nov         fri  ...         1    999         0  nonexistent
# 2  cellular   jun         thu  ...         3      6         2      success
# 3  cellular   apr         fri  ...         2    999         0  nonexistent
# 4  cellular   aug         fri  ...         1      3         1      success
#
#   emp_var_rate  cons_price_idx  cons_conf_idx  euribor3m  nr_employed  y
# ...

# %%
#question 1 a
df['job_admin'] = (df['job'] == 'admin.').astype(int)
df['job_blue-collar'] = (df['job'] == 'blue-collar').astype(int)
df['job_technician'] = (df['job'] == 'technician').astype(int)
df['job_services'] = (df['job'] == 'services').astype(int)
df['job_management'] = (df['job'] == 'management').astype(int)
df['job_retired'] = (df['job'] == 'retired').astype(int)
df['job_entrepreneur'] = (df['job'] == 'entrepreneur').astype(int)
df['job_self-employed'] = (df['job'] == 'self-employed').astype(int)
df['job_housemaid'] = (df['job'] == 'housemaid').astype(int)
df['job_unemployed'] = (df['job'] == 'unemployed').astype(int)
df['job_student'] = (df['job'] == 'student').astype(int)
df['job_unknown'] = (df['job'] == 'unknown').astype(int)

df['marital_divorced'] = (df['marital'] == 'divorced').astype(int)
df['marital_married'] = (df['marital'] == 'married').astype(int)
df['marital_single'] = (df['marital'] == 'single').astype(int)
df['marital_unknown'] = (df['marital'] == 'unknown').astype(int)

df['education_4y'] = (df['education'] == 'basic.4y').astype(int)
df['education_6y'] = (df['education'] == 'basic.6y').astype(int)
df['education_9y'] = (df['education'] == 'basic.9y').astype(int)
df['education_hs'] = (df['education'] == 'high.school').astype(int)
df['education_il'] = (df['education'] == 'basic.illiterate').astype(int)
df['education_pc'] = (df['education'] == 'professional.course').astype(int)
df['education_ud'] = (df['education'] == 'university.degree').astype(int)
df['education_unknown'] = (df['education'] == 'unknown').astype(int)

df['housing_yes'] = (df['housing'] == 'yes').astype(int)
df['housing_no'] = (df['housing'] == 'no').astype(int)

df['loan_yes'] = (df['loan'] == 'yes').astype(int)
df['loan_no'] = (df['loan'] == 'no').astype(int)
df['loan_uk'] = (df['loan'] == 'unkown').astype(int)

df['contact_cell'] = (df['contact'] == 'cellular').astype(int)
df['contact_tele'] = (df['contact'] == 'telephone').astype(int)

df['month_may'] = (df['month'] == 'may').astype(int)
df['month_jul'] = (df['month'] == 'jul').astype(int)
df['month_aug'] = (df['month'] == 'aug').astype(int)
df['month_jun'] = (df['month'] == 'jun').astype(int)
df['month_nov'] = (df['month'] == 'nov').astype(int)
df['month_apr'] = (df['month'] == 'apr').astype(int)
df['month_oct'] = (df['month'] == 'oct').astype(int)
df['month_sep'] = (df['month'] == 'sep').astype(int)
df['month_mar'] = (df['month'] == 'mar').astype(int)
df['month_dec'] = (df['month'] == 'dec').astype(int)

df['mon'] = (df['day_of_week'] == 'mon').astype(int)
df['tue'] = (df['day_of_week'] == 'tue').astype(int)
df['wed'] = (df['day_of_week'] == 'wed').astype(int)
df['thu'] = (df['day_of_week'] == 'thu').astype(int)
df['fri'] = (df['day_of_week'] == 'fri').astype(int)

df['poutcome_fail'] = (df['poutcome'] == 'failure').astype(int)
df['poutcome_succ'] = (df['poutcome'] == 'success').astype(int)
df['poutcome_none'] = (df['poutcome'] == 'nonexistent').astype(int)

# %%
df['campaign'] = (df['poutcome']).astype('Float64')

# %%
df.head()
# Out:
#    age          job  marital          education  default housing loan  \
# 0   44  blue-collar  married           basic.4y  unknown     yes   no
# 1   53   technician  married            unknown       no      no   no
# 2   28   management   single  university.degree       no     yes   no
# 3   39     services  married        high.school       no      no   no
# 4   55      retired  married           basic.4y       no     yes   no
#
#     contact month day_of_week  ...  month_mar  month_dec  mon  tue wed  thu  \
# 0  cellular   aug         thu  ...          0          0    0    0   0    1
# 1  cellular   nov         fri  ...          0          0    0    0   0    0
# 2  cellular   jun         thu  ...          0          0    0    0   0    1
# 3  cellular   apr         fri  ...          0          0    0    0   0    0
# 4  cellular   aug         fri  ...          0          0    0    0   0    0
#
#    fri  poutcome_fail  poutcome_succ  poutcome_none
# ...

# %%
X = df.drop(['y','job','marital','education','default','housing','loan','contact','month','day_of_week','poutcome','duration'], axis=1).astype('float64')

# %%
y = df['y'].values

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.3,      # 30% test
    random_state=1     # follow question request to use random seed 1
)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    roc_curve,
    auc,
    ConfusionMatrixDisplay
)

# %%
#to create the equation we use smf
df_smf = df.drop(['job','marital','education','default','housing','loan','contact','month','day_of_week','poutcome','duration'], axis=1).astype('float64')

# %%
df_smf.columns
# Out:
# Index(['age', 'campaign', 'pdays', 'previous', 'emp_var_rate',
#        'cons_price_idx', 'cons_conf_idx', 'euribor3m', 'nr_employed', 'y',
#        'job_admin', 'job_blue-collar', 'job_technician', 'job_services',
#        'job_management', 'job_retired', 'job_entrepreneur',
#        'job_self-employed', 'job_housemaid', 'job_unemployed', 'job_student',
#        'job_unknown', 'marital_divorced', 'marital_married', 'marital_single',
#        'marital_unknown', 'education_4y', 'education_6y', 'education_9y',
#        'education_hs', 'education_il', 'education_pc', 'education_ud',
#        'education_unknown', 'housing_yes', 'housing_no', 'loan_yes', 'loan_no',
#        'loan_uk', 'contact_cell', 'contact_tele', 'month_may', 'month_jul',
#        'month_aug', 'month_jun', 'month_nov', 'month_apr', 'month_oct',
#        'month_sep', 'month_mar', 'month_dec', 'mon', 'tue', 'wed', 'thu',
#        'fri', 'poutcome_fail', 'poutcome_succ', 'poutcome_none'],
#       dtype='object')

# %%
df_smf['jobselfemployed'] = df_smf['job_self-employed'] 
df_smf['jobbluecollar'] = df_smf['job_blue-collar']

# %%
df_smf = df_smf.drop(['job_self-employed','job_blue-collar'], axis=1).astype('float64')

# %%
results = smf.logit('y ~ age + campaign +  pdays +  previous +  emp_var_rate + cons_price_idx +  cons_conf_idx +  euribor3m +  nr_employed + job_admin + jobbluecollar+  job_technician +  job_services + job_management  +  job_retired +  job_entrepreneur + jobselfemployed +  job_housemaid +  job_unemployed +  job_student + job_unknown +  marital_divorced +  marital_married +  marital_single + marital_unknown +  education_4y +  education_6y +  education_9y + education_hs +  education_il +  education_pc +  education_ud + education_unknown +  housing_yes +  housing_no +  loan_yes +  loan_no + loan_uk +  contact_cell +  contact_tele +  month_may +  month_jul + month_aug +  month_jun +  month_nov + month_apr +  month_oct + month_sep +  month_mar +  month_dec +  mon +  tue +  wed +  thu + fri +  poutcome_fail +  poutcome_succ +  poutcome_none', data=df_smf).fit()
results.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.275932
#          Iterations 9
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[69], line 1
# ...

# %%
# ── question c. Fit logistic regression ───────USE SKLEARN!────────────────────────────────────────
model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)
#d predict
y_pred      = model.predict(X_test)          # predicted class labels (0 or 1)
y_pred_prob = model.predict_proba(X_test)[:, 1]   # P(default=1)
# Out:
# c:\Users\PC 14\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_logistic.py:406: ConvergenceWarning: lbfgs failed to converge after 1000 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=1000).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# ── d) Classification Report ─────────────────────────────────────────────────
report_dict = classification_report(y_test, y_pred, output_dict=True)
report_str  = classification_report(y_test, y_pred,
                                    target_names=['Class 0 (No Subscribe)',
                                                  'Class 1 (Subsribe)'])
print(report_str)
# Out:
#                         precision    recall  f1-score   support
#
# Class 0 (No Subscribe)       0.91      0.99      0.95     10924
#     Class 1 (Subsribe)       0.71      0.22      0.33      1433
#
#               accuracy                           0.90     12357
#              macro avg       0.81      0.60      0.64     12357
#           weighted avg       0.88      0.90      0.87     12357

# %%
# Per-class metrics
for cls_key, cls_label in [('0', 'Class 0 — No Subscribe'), ('1', 'Class 1 — Subscribe')]:
    p  = report_dict[cls_key]['precision']
    r  = report_dict[cls_key]['recall']
    f1 = report_dict[cls_key]['f1-score']
    s  = report_dict[cls_key]['support']
    print(f"{cls_label}  |  Precision: {p:.4f}  Recall: {r:.4f}  F1: {f1:.4f}  Support: {int(s)}")

# Bar chart of classification report
metrics   = ['precision', 'recall', 'f1-score']
cls0_vals = [report_dict['0'][m] for m in metrics]
cls1_vals = [report_dict['1'][m] for m in metrics]
x, width  = np.arange(3), 0.35

fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# — Plot 1: Classification report bar chart
ax = axes[0]
b0 = ax.bar(x - width/2, cls0_vals, width, label='Class 0', color='steelblue')
b1 = ax.bar(x + width/2, cls1_vals, width, label='Class 1', color='salmon')
ax.set_xticks(x); ax.set_xticklabels(['Precision', 'Recall', 'F1-Score'])
ax.set_ylim(0, 1.15); ax.set_ylabel('Score')
ax.set_title('Classification Report'); ax.legend()
for bar in list(b0) + list(b1):
    ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.02,
            f'{bar.get_height():.2f}', ha='center', va='bottom', fontsize=9)

# — Plot 2: Confusion matrix (question d)
ax = axes[1]
cm   = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                               display_labels=['No Subsribe', 'Subscribe'])
disp.plot(ax=ax, cmap='Blues', colorbar=False)
ax.set_title('Confusion Matrix')

# — Plot 3: ROC Curve
ax = axes[2]
fpr, tpr, _ = roc_curve(y_test, y_pred_prob)
roc_auc     = auc(fpr, tpr)
ax.plot(fpr, tpr, color='darkorange', lw=2, label=f'AUC = {roc_auc:.4f}')
ax.plot([0, 1], [0, 1], 'navy', lw=1.5, linestyle='--', label='Random (AUC = 0.50)')
ax.fill_between(fpr, tpr, alpha=0.1, color='darkorange')
ax.set_xlim([0, 1]); ax.set_ylim([0, 1.05])
ax.set_xlabel('False Positive Rate'); ax.set_ylabel('True Positive Rate')
ax.set_title('ROC Curve'); ax.legend(loc='lower right'); ax.grid(alpha=0.3)

plt.suptitle('Logistic Regression — Question 1 Dataset', fontsize=14, y=1.01)
plt.tight_layout()
plt.show()
# Out:
# Class 0 — No Subscribe  |  Precision: 0.9059  Recall: 0.9882  F1: 0.9453  Support: 10924
# Class 1 — Subscribe  |  Precision: 0.7075  Recall: 0.2177  F1: 0.3330  Support: 1433

# %% [markdown]
# The results show that the logistic regression model predicts the outcome y better than a random guess as the AUC is higher than 0.5. From the confiusion matrix we can also see that the true subribers are the highest in number at 10795. There are 1121 subsribers that are predicted as non-subsribers. There are 129 non subsribers that are predicted as subsribers.
#
# From the barplot of the classification report we can also see the limitations of this model. The model is doing well for Class 0 achieving >90% for Precision, Recall and F1 score. However when evaluating Class 1 the score is much reduced, only acheiving 22% in recall and 33% in F1 score respectively. This shows that the model is only able to predict 312 subsribers from a total of 1433 (support).
#
# The methods to improve this could be using adding steps for balanced bagging or SMOTE as the dataset is imbalanced.

# %%
#question e
cm = confusion_matrix(y_test, y_pred)

# %%
sensitivity = cm[1,1] / (cm[1,1] + cm[1,0])  # TP/(TP+FN)
specificity = cm[0,0] / (cm[0,0] + cm[0,1])  # TN/(TN+FP)

# %%
print(sensitivity)
# Out:
# 0.21772505233775297

# %%
print(specificity)
# Out:
# 0.9881911387770047

# %% [markdown]
# #### Question 1 f
#
# Both Linear Discriminant Anlaysis(LDA) and Quadratic Discriminant Analysis(QDA) assumes that the observations from each class are drawn from a Gaussian distribution. Our dataset shows an imbalanced dataset where there is a larger number of class 0 compared to class 1 and therefore unlikely to be gaussian in nature, therefore, Logistic regression is more suited for this dataset.
